# %% [markdown]
# <a href="https://colab.research.google.com/github/run-llama/llama_index/blob/main/docs/docs/examples/evaluation/retrieval/retriever_eval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Retrieval Evaluation
#
# This notebook uses our `RetrieverEvaluator` to evaluate the quality of any Retriever module defined in LlamaIndex.
#
# We specify a set of different evaluation metrics: this includes hit-rate, MRR, Precision, Recall, AP, and NDCG. For any given question, these will compare the quality of retrieved results from the ground-truth context.
#
# To ease the burden of creating the eval dataset in the first place, we can rely on synthetic data generation.

# %% [markdown]
# ## Setup
#
# Here we load in data (PG essay), parse into Nodes. We then index this data using our simple vector index and get a retriever.

# %%
# %pip install llama-index-llms-openai llama-index-readers-file matplotlib

# %%
import nest_asyncio


nest_asyncio.apply()

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.core.node_parser import SentenceSplitter
# from llama_index.llms.openai import OpenAI

# %% [markdown]
# Download Data

# %%
# !mkdir -p 'data/paul_graham/'
# !wget 'https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt' -O 'data/paul_graham/paul_graham_essay.txt'

# %%
# documents = SimpleDirectoryReader("./data/paul_graham/").load_data()
documents = SimpleDirectoryReader("/home/daimler/workspaces/agents-course-huggingface/chat-neus-catala/data/documents").load_data()

# %%
node_parser = SentenceSplitter(chunk_size=512)
nodes = node_parser.get_nodes_from_documents(documents, show_progress=True )
# Out:
# Parsing nodes:   0%|          | 0/516 [00:00<?, ?it/s]

# %%
# by default, the node ids are set to random uuids. To ensure same id's per run, we manually set them.
for idx, node in enumerate(nodes):
    node.id_ = f"node_{idx}"

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Settings
from llama_index.core.agent.workflow import AgentWorkflow
from llama_index.llms.ollama import Ollama
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
import asyncio
import os

# Settings control global defaults
Settings.embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-base-en-v1.5")
Settings.llm = Ollama(model="llama3.2:latest", request_timeout=360.0)
# llm = OpenAI(model="gpt-4")

# %%
import torch
torch.cuda.empty_cache()

vector_index = VectorStoreIndex(nodes)
retriever = vector_index.as_retriever(similarity_top_k=2)

# %% [markdown]
# ### Try out Retrieval
#
# We'll try out retrieval over a simple dataset.

# %%
# retrieved_nodes = retriever.retrieve("What did the author do growing up?")
retrieved_nodes = retriever.retrieve("Que havien de passar Les presoneres de Ravensbrück abans d incorporar-se als treballs forçats?")
retrieved_nodes
# Out:
# [NodeWithScore(node=TextNode(id_='node_178', embedding=None, metadata={'page_label': '87', 'file_name': 'NeusCatala-llibre.pdf', 'file_path': '/home/daimler/workspaces/agents-course-huggingface/chat-neus-catala/data/documents/NeusCatala-llibre.pdf', 'file_type': 'application/pdf', 'file_size': 6741968, 'creation_date': '2025-03-21', 'last_modified_date': '2025-03-13'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='623a3cbe-fd46-4548-ae1b-6f0ba75ede8b', node_type='4', metadata={'page_label': '87', 'file_name': 'NeusCatala-llibre.pdf', 'file_path': '/home/daimler/workspaces/agents-course-huggingface/chat-neus-catala/data/documents/NeusCatala-llibre.pdf', 'file_type': 'application/pdf', 'file_size': 6741968, 'creation_date': '2025-03-21', 'last_modified_date': '2025-03-13'}, hash='c3b7ba47bf40f4734a8b6deba22cb020dc7876683319d4048bc6c8f6dcf4dcc4'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='38ca48cd-bb49-4c70-b92f-9d0dfd4c01a1', node_type='1', metadata={'page_label': '87', 'file_name': 'NeusCatala-llibre.pdf', 'file_path': '/home/daimler/workspaces/agents-course-huggingface/chat-neus-catala/data/documents/NeusCatala-llibre.pdf', 'file_type': 'application/pdf', 'file_size': 6741968, 'creation_date': '2025-03-21', 'last_modified_date': '2025-03-13'}, hash='bcfe99a998ae28888990c00a2ff8528e7dae02baa9306cdd466ae3c2fc9c49a4')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Encara es pregunta de\nquin país seria la dona que li sal-\nvà la vida...\nTreballs forçats i càstigs\nLes presoneres de Ravensbrück\nhavien de passar una quarante-\nna abans d’incorporar-se als tre-\nballs forçats. Però el grup de la\nNeus no l’acabà. Als 20 dies ja\nles portaren al recompte a la pla-\nça central. La sirena les arranca-\nva del catre a les 3 de la matina-\nda: tocava vestir-se, calçar-se, fer\nel llit, prendre el cafè i passar el\nprimer recompte davant de la\nbarraca. A l’hivern, l’aigua esta-\nva gelada i no es podien ni ren-\ntar. Després, desfilaven cap a la\nplaça central del camp on, a les\n4 en punt, havien de formar en\nquadres. Les feien estar dretes i\nimmòbils durant 5 hores, a 22\ngraus sota zero. “I esperàvem\naterrides quin seria el primer crim\ndel dia”, rememora la Neus.\nLa primera feina que els obli-\ngaren a fer a les de la barraca\n22 fou a pic i pala. Les tragueren\ndel camp en grups de quaranta.\n“Travessàvem Fürstenberg amb una\naixada enorme a l’esquena. Un cop\narribàvem a una esplanada, haví-\nem de desplaçar un  munt de terra\nde dreta a esquerra i a l’inrevés.\nVolien esgotar-nos i valorar les nos-\ntres forces”, assegura la Neus. El\nprimer toc de xiulet del SS de torn,\ni les 40 pales estaven en movi-\nment. Les dones de caràcter més', mimetype='text/plain', start_char_idx=1525, end_char_idx=2788, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.6955495215777152),
#  NodeWithScore(node=TextNode(id_='node_326', embedding=None, metadata={'page_label': '151', 'file_name': 'NeusCatala-llibre.pdf', 'file_path': '/home/daimler/workspaces/agents-course-huggingface/chat-neus-catala/data/documents/NeusCatala-llibre.pdf', 'file_type': 'application/pdf', 'file_size': 6741968, 'creation_date': '2025-03-21', 'last_modified_date': '2025-03-13'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='f12d9386-7d8b-4ead-8bc8-ff6d608da316', node_type='4', metadata={'page_label': '151', 'file_name': 'NeusCatala-llibre.pdf', 'file_path': '/home/daimler/workspaces/agents-course-huggingface/chat-neus-catala/data/documents/NeusCatala-llibre.pdf', 'file_type': 'application/pdf', 'file_size': 6741968, 'creation_date': '2025-03-21', 'last_modified_date': '2025-03-13'}, hash='450fa097aa6b4107b28b4bfc6289552870ca5037290eaf10456810e9d425af11'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='6cb65eb5-a4a6-4c6e-9507-d4cc2c5bf9dd', node_type='1', metadata={'page_label': '151', 'file_name': 'NeusCatala-llibre.pdf', 'file_path': '/home/daimler/workspaces/agents-course-huggingface/chat-neus-catala/data/documents/NeusCatala-llibre.pdf', 'file_type': 'application/pdf', 'file_size': 6741968, 'creation_date': '2025-03-21', 'last_modified_date': '2025-03-13'}, hash='6e107fe0369540ca38a998a5c791828e4870de940b3276365db069ebc28e6f99'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='c4fcf9dc-8479-4b60-989c-9be2ca230922', node_type='1', metadata={}, hash='be767adc68a8fac21b8f5834ada8a393d35eb883bca730d9986323608e2a56c1')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Peregrinatge a Ravensbrück. Maig 2005.\nPàg. 93 - La Neus Català amb la seva estimada “Titi”, Teresa Menot, en un peregrinatge al camp de  Ravensbrück. Arxiu\nfamiliar Neus Català\nPàg. 94 - “Nosaltres, les deportades quan ens trobem sempre riem, perqué sóm les tres del Kommando de les Gandu-\nles,  per això aquestes rialles!! Els altres estan mirant perquè riem com a ximples”  Trobada de tres dones del Kommando\nFaul (Kommando de les Gandules) d’Holleischen durant el peregrinatge al camp de Ravensbrück. Maig 2005.\nPàg. 97 - - - - - “Les valentes, al camp de Ravensbrück perquè quan plorava alguna la consolàvem, i les gandules a\nHolleischen””Qui no plorava de cara, plorava d’amagat, a qui no li podien caure les llàgrimes allà tancades..era nor-\nmal...!” La Neus Català i l’Assumpta Montellà, autora del llibre sobre La maternitat d’Elna. Bressol dels exiliats . Xerrada\nsobre xarxes d’exili, solidaritat i Resistència. Centre Social de Sants. 10 d’octubre de 2006.  Foto-muntatge de Maria\nPrenafeta.\nPàg. 98 - La Neus Català a l’interior de la cel.la de la presó dedicada a les deportades espanyoles. Memorial de\nRavensbrück. Durant el peregrinatge al camp de Ravensbrück. Maig 2005\nPàg.', mimetype='text/plain', start_char_idx=1493, end_char_idx=2684, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.6838852637493945)]

# %%
from llama_index.core.response.notebook_utils import display_source_node

for node in retrieved_nodes:
    display_source_node(node, source_length=1000)
# Out:
# **Node ID:** node_178<br>**Similarity:** 0.6955495215777152<br>**Text:** Encara es pregunta de
# quin país seria la dona que li sal-
# và la vida...
# Treballs forçats i càstigs
# Les presoneres de Ravensbrück
# havien de passar una quarante-
# na abans d’incorporar-se als tre-
# balls forçats. Però el grup de la
# Neus no l’acabà. Als 20 dies ja
# les portaren al recompte a la pla-
# ça central. La sirena les arranca-
# va del catre a les 3 de la matina-
# da: tocava vestir-se, calçar-se, fer
# el llit, prendre el cafè i passar el
# primer recompte davant de la
# barraca. A l’hivern, l’aigua esta-
# va gelada i no es podien ni ren-
# tar. Després, desfilaven cap a la
# plaça central del camp on, a les
# 4 en punt, havien de formar en
# quadres. Les feien estar dretes i
# immòbils durant 5 hores, a 22
# graus sota zero. “I esperàvem
# aterrides quin seria el primer crim
# del dia”, rememora la Neus.
# La primera feina que els obli-
# garen a fer a les de la barraca
# 22 fou a pic i pala. Les tragueren
# del camp en grups de quaranta.
# “Travessàvem Fürstenberg amb una
# aixada enorme a l’esquena. Un cop
# arribàvem...<br>
# **Node ID:** node_326<br>**Similarity:** 0.6838852637493945<br>**Text:** Peregrinatge a Ravensbrück. Maig 2005.
# Pàg. 93 - La Neus Català amb la seva estimada “Titi”, Teresa Menot, en un peregrinatge al camp de  Ravensbrück. Arxiu
# familiar Neus Català
# Pàg. 94 - “Nosaltres, les deportades quan ens trobem sempre riem, perqué sóm les tres del Kommando de les Gandu-
# les,  per això aquestes rialles!! Els altres estan mirant perquè riem com a ximples”  Trobada de tres dones del Kommando
# Faul (Kommando de les Gandules) d’Holleischen durant el peregrinatge al camp de Ravensbrück. Maig 2005.
# Pàg. 97 - - - - - “Les valentes, al camp de Ravensbrück perquè quan plorava alguna la consolàvem, i les gandules a
# Holleischen””Qui no plorava de cara, plorava d’amagat, a qui no li podien caure les llàgrimes allà tancades..era nor-
# mal...!” La Neus Català i l’Assumpta Montellà, autora del llibre sobre La maternitat d’Elna. Bressol dels exiliats . Xerrada
# sobre xarxes d’exili, solidaritat i Resistència. Centre Social de Sants. 10 d’octubre de 2006.  Foto-muntatge de Maria
# Pren...<br>

# %% [markdown]
# ## Build an Evaluation dataset of (query, context) pairs
#
# Here we build a simple evaluation dataset over the existing text corpus.
#
# We use our `generate_question_context_pairs` to generate a set of (question, context) pairs over a given unstructured text corpus. This uses the LLM to auto-generate questions from each context chunk.
#
# We get back a `EmbeddingQAFinetuneDataset` object. At a high-level this contains a set of ids mapping to queries and relevant doc chunks, as well as the corpus itself.

# %%
from llama_index.core.evaluation import (
    generate_question_context_pairs,
    EmbeddingQAFinetuneDataset
    )
from llama_index.core.llama_dataset.legacy.embedding import DEFAULT_QA_GENERATE_PROMPT_TMPL

# %%
qa_dataset = generate_question_context_pairs(
    nodes, 
    # llm=llm, 
    num_questions_per_chunk=2,
    qa_generate_prompt_tmpl=DEFAULT_QA_GENERATE_PROMPT_TMPL+ "\n Please respond directly to the question without any introductory text or formatting.",


)
# Out:
#   0%|          | 3/1142 [00:02<14:50,  1.28it/s]/home/daimler/workspaces/agents-course-huggingface/.venv/lib/python3.11/site-packages/llama_index/core/llama_dataset/legacy/embedding.py:102: UserWarning: Fewer questions generated (1) than requested (2).
#   warnings.warn(
# 100%|██████████| 1142/1142 [12:44<00:00,  1.49it/s]

# %%
queries = qa_dataset.queries.values()
print(list(queries)[:20])
# Out:
# ['What is the 10th number in the given sequence?', 'Is the ISBN a unique identifier?', 'Who is responsible for editing the book and how can you contact them?', "What is the publication's Dipòsit Legal number?", 'What is the name of the author of the book "Memòria i lluita"?', 'Who are the individuals mentioned as having the same last name "Belenguer Mercadé"?', 'What type of assessment will you be conducting - a multiple-choice test or a short-answer examination?', 'What is the purpose of creating a presentation, and what are its components?', 'Is there a specific type of presentation mentioned in the given context information that needs to be tested on the quiz/examination?', 'What is the number of lines in the given context information?', 'Is the number provided 6 being presented as a line count for a poem or a code?', 'What organization is represented by the phrase "Fundació Pere Ardiaca" and who is its president?', 'Who is described as being "la primera a posar-se-hi", indicating that they were the first to take action?', "What is Neus' role in the Fundació Pere Ardiaca?", 'Who is the person that was suggested to have an assistant due to concerns about Neus being old?', 'Who wrote the letter and what is the name of their companion mentioned in the letter?', 'What kind of experience does the author of the letter consider themselves to have, according to the statement about their life being "consumida minut a minut"?', "What was Neus's response when her father shouted at her mother as a child?", 'Who is the person being honored with a presentation of a book by Mercé Civit?', 'What role has Ella played in her life that can be considered as a good representation of a communist?']

# %%
# [optional] save
qa_dataset.save_json("pg_eval_dataset.json")

# %%
# [optional] load
qa_dataset = EmbeddingQAFinetuneDataset.from_json("pg_eval_dataset.json")

# %% [markdown]
# ## Use `RetrieverEvaluator` for Retrieval Evaluation
#
# We're now ready to run our retrieval evals. We'll run our `RetrieverEvaluator` over the eval dataset that we generated.

# %% [markdown]
# We define two functions: `get_eval_results` and also `display_results` that run our retriever over the dataset.

# %%
include_cohere_rerank = False

if include_cohere_rerank:
    # !pip install cohere -q

# %%
from llama_index.core.evaluation import RetrieverEvaluator

metrics = ["hit_rate", "mrr", "precision", "recall", "ap", "ndcg"]

if include_cohere_rerank:
    metrics.append(
        "cohere_rerank_relevancy"  # requires COHERE_API_KEY environment variable to be set
    )

retriever_evaluator = RetrieverEvaluator.from_metric_names(
    metrics, retriever=retriever
)

# %%
# try it out on a sample query
sample_id, sample_query = list(qa_dataset.queries.items())[1]
sample_expected = qa_dataset.relevant_docs[sample_id]

eval_result = retriever_evaluator.evaluate(sample_query, sample_expected)
print(eval_result)
# Out:
# Query: Is the ISBN a unique identifier?
# Metrics: {'hit_rate': 1.0, 'mrr': 1.0, 'precision': 0.5, 'recall': 1.0, 'ap': 1.0, 'ndcg': 1.0}

# %%
for (sample_id, sample_query) in list(qa_dataset.queries.items()):
    sample_expected = qa_dataset.relevant_docs[sample_id]

    eval_result = retriever_evaluator.evaluate(sample_query, sample_expected)
    print(eval_result)
# Out:
# Query: What is the 10th number in the given sequence?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Is the ISBN a unique identifier?
# Metrics: {'hit_rate': 1.0, 'mrr': 1.0, 'precision': 0.5, 'recall': 1.0, 'ap': 1.0, 'ndcg': 1.0}
#
# Query: Who is responsible for editing the book and how can you contact them?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What is the publication's Dipòsit Legal number?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What is the name of the author of the book "Memòria i lluita"?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who are the individuals mentioned as having the same last name "Belenguer Mercadé"?
# Metrics: {'hit_rate': 1.0, 'mrr': 1.0, 'precision': 0.5, 'recall': 1.0, 'ap': 1.0, 'ndcg': 1.0}
#
# Query: What type of assessment will you be conducting - a multiple-choice test or a short-answer examination?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What is the purpose of creating a presentation, and what are its components?
# Metrics: {'hit_rate': 1.0, 'mrr': 1.0, 'precision': 0.5, 'recall': 1.0, 'ap': 1.0, 'ndcg': 1.0}
#
# Query: Is there a specific type of presentation mentioned in the given context information that needs to be tested on the quiz/examination?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What is the number of lines in the given context information?
# Metrics: {'hit_rate': 1.0, 'mrr': 0.5, 'precision': 0.5, 'recall': 1.0, 'ap': 0.5, 'ndcg': 0.6309297535714575}
#
# Query: Is the number provided 6 being presented as a line count for a poem or a code?
# Metrics: {'hit_rate': 1.0, 'mrr': 1.0, 'precision': 0.5, 'recall': 1.0, 'ap': 1.0, 'ndcg': 1.0}
#
# Query: What organization is represented by the phrase "Fundació Pere Ardiaca" and who is its president?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who is described as being "la primera a posar-se-hi", indicating that they were the first to take action?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What is Neus' role in the Fundació Pere Ardiaca?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who is the person that was suggested to have an assistant due to concerns about Neus being old?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who wrote the letter and what is the name of their companion mentioned in the letter?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What kind of experience does the author of the letter consider themselves to have, according to the statement about their life being "consumida minut a minut"?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What was Neus's response when her father shouted at her mother as a child?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who is the person being honored with a presentation of a book by Mercé Civit?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What role has Ella played in her life that can be considered as a good representation of a communist?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who is Neus and what type of content does she provide that is valuable for learning?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What was Mià's experience at the Ravensbrück camp?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who is Neus, and why is she mentioned as a reference point for Merce Civit's work?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What is the purpose of the document?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who is referred to as "You" at the beginning of the introduction?
# Metrics: {'hit_rate': 1.0, 'mrr': 1.0, 'precision': 0.5, 'recall': 1.0, 'ap': 1.0, 'ndcg': 1.0}
#
# Query: What is the purpose of the provided context information, and what type of examination is it related to?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Is the context information about a specific event, topic, or subject that will be tested in the upcoming quiz/examination?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What is the primary goal of creating a book about Neus Català?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who are some of the groups that have been historically silenced and are being recognized by the Fundació Pere Ardiaca?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What was the occupation of La Neus Català before she became involved with the socialist movement?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who led the organization of the Joventuts Socialistes Unificades de Catalunya?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What was La Neus' occupation before joining the Joventuts Socialistes Unificades de Catalunya, and where did she work?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who were some of

# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who was substituted by Joaquim Puig Pedemunt, and what is mentioned as the reason for this substitution?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What is the name of the person who was suspended from militancy in Josep Serradell in 1949?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who assumes the responsibility of secretariat of organization of PSUC and is also substituted as a member of the front of the secretariat in 1954?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What is the name of the event for which Josep Serradell returns to Catalunya in 1956-1957?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What office did Serradell hold from 1978 until he left, which was then taken over by Paco Trives?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who was responsible for pleging from the Comitè Executiu in 1978?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What year was Josep Serradell expelled from the PSUC due to allegations of conducting anti-governmental activities?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who is the author mentioned as cooperating closely with En Josep Serradell on his biography?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What was the title of the second book written by Josep Serradell, published in 1998?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who else collaborated with Josep Serradell in the construction of his biography?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What was the title of the organ of the Comitè Central del Partit dels Comunistes de Catalunya-PCC from April to May 1982?
# Metrics: {'hit_rate': 1.0, 'mrr': 1.0, 'precision': 0.5, 'recall': 1.0, 'ap': 1.0, 'ndcg': 1.0}
#
# Query: Which publication, written by Medina Rodriguez in September 1993, provides a historical overview of the Partit dels Comunistes de Catalunya from 1982-1992?
# Metrics: {'hit_rate': 1.0, 'mrr': 1.0, 'precision': 0.5, 'recall': 1.0, 'ap': 1.0, 'ndcg': 1.0}
#
# Query: What was the recipient of the author's sincere gratitude?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who was responsible for making the book possible?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who wrote a book that was recommended by José Serradell, and what is the title of this book?
# Metrics: {'hit_rate': 1.0, 'mrr': 1.0, 'precision': 0.5, 'recall': 1.0, 'ap': 1.0, 'ndcg': 1.0}
#
# Query: What type of sources were consulted during the research for the book?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What were the titles of the three volumes written by Miquel Caminal about Joan Comorera?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who wrote "La onda larga del capitalismo español" and what is the year of publication mentioned?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What was the title of the issue of L'Avenç magazine that featured an article about PSUC, a socialist organization?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who wrote the book "El Partido Comunista de España en la II República"?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who was the editor of the book "Diccionari dels Partits Polítics de Catalunya, segle XX"?
# Metrics: {'hit_rate': 1.0, 'mrr': 1.0, 'precision': 0.5, 'recall': 1.0, 'ap': 1.0, 'ndcg': 1.0}
#
# Query: Was the disappearance of the PCE-PSUC an enigmatic event according to Gregorio Morán's article?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What was the title of the book written by Semprún about Federico Sánchez, published in 1997?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: Who wrote the article "Una història optimista" which was published in 1999?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What was the title of the book published by Edicions 62 in Barcelona in 1999?
# Metrics: {'hit_rate': 1.0, 'mrr': 1.0, 'precision': 0.5, 'recall': 1.0, 'ap': 1.0, 'ndcg': 1.0}
#
# Query: Who wrote the book "Historia oculta del PCE" published by Ediciones Temas de Hoy in Madrid in 2000?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}
#
# Query: What are the main topics covered by the books "Heriberto Quiñones y el movimiento comunista en España (1931-1942)" and "El PSUC: La primera resistència" by Josep Pallach?
# Metrics: {'hit_rate': 1.0, 'mrr': 1.0, 'precision': 0.5, 'recall': 1.0, 'ap': 1.0, 'ndcg': 1.0}
#
# Query: Who edited the book "Rojos contra Franco, Historia del PSUC, 1939-1947"?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}

# %%
# try it out on an entire dataset
eval_results = await retriever_evaluator.aevaluate_dataset(qa_dataset)

# %%
import pandas as pd


def display_results(name, eval_results):
    """Display results from evaluate."""

    metric_dicts = []
    for eval_result in eval_results:
        metric_dict = eval_result.metric_vals_dict
        metric_dicts.append(metric_dict)

    full_df = pd.DataFrame(metric_dicts)

    columns = {
        "retrievers": [name],
        **{k: [full_df[k].mean()] for k in metrics},
    }

    if include_cohere_rerank:
        crr_relevancy = full_df["cohere_rerank_relevancy"].mean()
        columns.update({"cohere_rerank_relevancy": [crr_relevancy]})

    metric_df = pd.DataFrame(columns)

    return metric_df

# %%
display_results("top-2 eval", eval_results)
# Out:
#    retrievers  hit_rate       mrr  precision    recall        ap      ndcg
# 0  top-2 eval  0.183691  0.159579   0.091846  0.183691  0.159579  0.165893
